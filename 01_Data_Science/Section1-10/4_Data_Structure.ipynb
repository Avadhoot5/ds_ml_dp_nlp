# %% [markdown]
# ## Assignments of section 4

# %% [markdown]
# ### Lists

# %%
### Assignment 5: Filtering Lists
# Create a new list containing only the even numbers from the list created in Assignment 1 using a list comprehension. Print the new list.

filtered_list = [num for num in range(1, 50) if num%2==0]
print(filtered_list)

# %%
### Assignment 6: List Methods
# Create a list of random numbers and sort it in ascending and descending order. Remove the duplicates from the list and print the modified list.

import random

random_list = [random.randint(1,100) for num in range(1,100)]

random_list.sort()
print(random_list)
random_list.reverse()
print(random_list)

modified_list = set(random_list)
print(list(modified_list))

# %%
### Assignment 7: Nested Lists
# Create a nested list representing a 3x3 matrix and print the matrix. Access and print the element at the second row and third column.

nested_list = [[random.randint(1,5) for _ in range(3)] for _ in range(3)]
print(nested_list)

nested_list[1][2]

# %%
### Assignment 8: List of Dictionaries
# Create a list of dictionaries where each dictionary represents a student with keys 'name' and 'score'. Sort the list of dictionaries by the 'score' in descending order and print the sorted list.

students = [
    {'name': 'Raj', 'score': 39},
    {'name': 'Akash', 'score': 42},
    {'name': 'Andrew', 'score': 98},
    {'name': 'Shyam', 'score': 83},
]

sorted_list = sorted(students, key=lambda x: x['score'], reverse=True)
sorted_list

# %%
### Assignment 9: Matrix Transposition
# Write a function that takes a 3x3 matrix (nested list) as input and returns its transpose. Print the original and transposed matrices.

def transpose_matrix(matrix):
    n = len(matrix)
    new_matrix = [[matrix[row][col] for row in range(n)] for col in range(n)]

    return new_matrix

matrix = [[random.randint(1,5) for _ in range(3)] for _ in range(3)]

print('Input Matrix')
for row in matrix:
    print(row)

print('Output Matrix')
output_matrix = transpose_matrix(matrix)
for row in output_matrix:
    print(row)

# %%
### Assignment 10: Flattening a Nested List
# Write a function that takes a nested list and flattens it into a single list. Print the original and flattened lists.

nested_list = [[random.randint(1,5) for _ in range(3)] for _ in range(3)]
n = len(nested_list)

flatten_list = [nested_list[row][col] for row in range(n) for col in range(n)]

print('Nested List\n', nested_list)

print('Flattened List\n', flatten_list)

# %%
### Assignment 11: List Manipulation
# Create a list of the first 10 positive integers. Remove the elements at indices 2, 4, and 6, and insert the element '99' at index 5. Print the modified list.

new_list = [i for i in range(1,11)]

for i in (6,4,2):
    new_list.pop(i)

new_list.insert(5, 99)

print(new_list)

# %%
### Assignment 12: List Zipping
# Create two lists of the same length. Use the `zip` function to combine these lists into a list of tuples and print the result.

list_a = [random.randint(1, 5) for _ in range(5)]
list_b = [random.randint(1, 5) for _ in range(5)]

final_list = [(i, j) for i, j in zip(list_a, list_b)]
print(final_list)

# %%
### Assignment 13: List Reversal
# Write a function that takes a list and returns a new list with the elements in reverse order. Print the original and reversed lists.

def reverse(list):
    return list[::-1]

new_list = [i for i in range(1,11)]
rev_list = reverse(new_list)

print(new_list)
print(rev_list)

# %%
### Assignment 14: List Rotation
# Write a function that rotates a list by n positions. Print the original and rotated lists.

new_list = [i for i in range(1,11)]

def reverse_list(arr):
    i, j = 0, len(arr) - 1
    while (i < j):
        arr[i], arr[j] = arr[j], arr[i]
        i += 1
        j -= 1
    return arr

def rotate_by_n(list, d):
    n = len(list)
    d = d % n
    rev_a = reverse_list(list[:d])
    rev_b = reverse_list(list[d:])
    rev_c = rev_a + rev_b
    final_arr = reverse_list(rev_c)
    return final_arr

rotate_list = rotate_by_n(new_list, 3)
print(new_list)
print(rotate_list)

# %%
### Assignment 15: List Intersection
# Write a function that takes two lists and returns a new list containing only the elements that are present in both lists. Print the intersected list.

list_a = [random.randint(1, 10) for i in range(1,11)]
list_b = [random.randint(1, 10) for i in range(1,11)]

def intersect(a, b):
    return list({element_a for element_a in a if element_a in b})

print(f'List A: {list_a}')
print(f'List b: {list_b}')

print(intersect(list_a, list_b))

# %% [markdown]
# ### Sets

# %%
import random

# %%
### Assignment 1: Creating and Accessing Sets
#Create a set with the first 10 positive integers. Print the set.

first_set = {i for i in range(1, 11)}
first_set

# %%
### Assignment 2: Adding and Removing Elements
#Add the number 11 to the set created in Assignment 1. Then remove the number 1 from the set. Print the modified set.

first_set.add(11)
print(first_set)
first_set.remove(11)
print(first_set)

# %%
### Assignment 3: Set Operations
#Create two sets: one with the first 5 positive integers and another with the first 5 even integers. Perform and print the results of union, intersection, difference, and symmetric difference operations on these sets.

positive_integers = {i for i in range(1, 6)}
even_integers = {i for i in range(1, 11) if i % 2 == 0}

print('Pos Integers', positive_integers)
print('Even Integers', even_integers)

# Union

union_set = positive_integers.union(even_integers)
print(union_set)

# Intersection
intersection_set = positive_integers.intersection(even_integers)
print(intersection_set)

# Difference
difference_set = positive_integers.difference(even_integers)
print(difference_set)

# Symmetric Difference
symm_diff = positive_integers.symmetric_difference(even_integers)
print(symm_diff)

# %%
### Assignment 4: Set Comprehensions
#Create a new set containing the squares of the first 10 positive integers using a set comprehension. Print the new set.

square_set = {i*i for i in range(1,11)}
print(square_set)

# %%
### Assignment 5: Filtering Sets
#Create a new set containing only the even numbers from the set created in Assignment 1 using a set comprehension. Print the new set.

even_num_set = {i for i in first_set if i%2 == 0}
even_num_set

# %%
### Assignment 6: Set Methods
#Create a set with duplicate elements and remove the duplicates using set methods. Print the modified set.

dup_set = {random.randint(1,5) for _ in range(1, 10)}
dup_set

# %%
### Assignment 7: Subsets and Supersets
#Create two sets: one with the first 5 positive integers and another with the first 3 positive integers. Check if the second set is a subset of the first set and if the first set is a superset of the second set. Print the results.

first_5 = {i for i in range(1, 6)}
first_3 = {i for i in range(1, 4)}

print(f'Is First 3 a subset of First 5: ', first_3.issubset(first_5))
print(f'Is First 5 a superset of First 3: ', first_5.issuperset(first_3))

# %%
### Assignment 8: Frozenset
#Create a frozenset with the first 5 positive integers. Print the frozenset.

frozenset = {i for i in range(1, 6)}
frozenset

# %%
### Assignment 9: Set and List Conversion
#Create a set with the first 5 positive integers. Convert it to a list, append the number 6, and convert it back to a set. Print the resulting set.

convert_set = {i for i in range(1, 6)}
convert_list = list(convert_set)
convert_list.append(6)
set(convert_list)

# %%
### Assignment 10: Set and Dictionary
#Create a dictionary with set keys and integer values. Print the dictionary.

d = {
    frozenset([1, 2]): 10,
    frozenset([3, 4]): 20
}

d

# %%
### Assignment 11: Iterating Over Sets
#Create a set and iterate over the elements, printing each element.

temp_set = {random.randint(1,10) for i in range(1, 11)}
for i in temp_set:
    print(i)

# %%
### Assignment 12: Removing Elements from Sets
#Create a set and remove elements from it until it is empty. Print the set after each removal.

temp_set = {random.randint(1,10) for i in range(1, 11)}

print(temp_set)

for i in range(len(temp_set)):
    popped_element = temp_set.pop()
    print(popped_element)

print(temp_set)

# %%
### Assignment 13: Set Symmetric Difference Update
#Create two sets and update the first set with the symmetric difference of the two sets. Print the modified first set.

first_set = {random.randint(1, 5) for _ in range(1, 11)}
second_set = {random.randint(1, 10) for _ in range(1, 11)}

print('First set: ',first_set)
print('Second set: ',second_set)

first_set.symmetric_difference_update(second_set)
print(first_set)

# %%
### Assignment 14: Set Membership Testing
#Create a set and test if certain elements are present in the set. Print the results.

temp_set = {random.randint(1,10) for i in range(1, 11)}

if (2) in temp_set:
    print('Yes')

# %%
### Assignment 15: Set of Tuples
#Create a set containing tuples, where each tuple contains two elements. Print the set.

temp_set = {(random.randint(1,10), random.randint(1,10)) for i in range(1, 11)}
print(temp_set)

# %% [markdown]
# ### Tuples

# %%
# ### Assignment 1: Creating and Accessing Tuples
# Create a tuple with the first 10 positive integers. Print the tuple.

first_tuple = tuple(i for i in range(1, 11))
print(first_tuple)
print(type(first_tuple))

# %%
# ### Assignment 2: Accessing Tuple Elements
# Print the first, middle, and last elements of the tuple created in Assignment 1.

n = len(first_tuple)
print(first_tuple[0])
print(first_tuple[n//2 - 1], first_tuple[n//2])
print(first_tuple[n-1])

# %%
# ### Assignment 3: Tuple Slicing
# Print the first three elements, the last three elements, and the elements from index 2 to 5 of the tuple created in Assignment 1.

n = len(first_tuple)
print(first_tuple[:3])
print(first_tuple[n-3:])
print(first_tuple[2:6])

# %%
# ### Assignment 4: Nested Tuples
# Create a nested tuple representing a 3x3 matrix and print the matrix. Access and print the element at the second row and third column.

nested_tuple = tuple(tuple(random.randint(1,9) for _ in range(3)) for _ in range(3))

for row in nested_tuple:
    print(row)

print(nested_tuple[1][2])

# %%
# ### Assignment 5: Tuple Concatenation
# Concatenate two tuples: (1, 2, 3) and (4, 5, 6). Print the resulting tuple.

first_tup = tuple(i for i in range(1, 6))
second_tup = tuple(i for i in range(6, 11))

print(first_tup)
print(second_tup)

concatenated_tup = first_tup + second_tup
print(concatenated_tup)

# %%
# ### Assignment 6: Tuple Methods
# Create a tuple with duplicate elements and count the occurrences of an element. Find the index of the first occurrence of an element in the tuple.

dup_tup = tuple(random.randint(1,4) for _ in range(1, 11))
print(dup_tup)

def count_occurence(element):
    return dup_tup.count(element)

print('Occurence or element 4:', count_occurence(4))

first_occurence = set()
for i in dup_tup:
    first_occurence.add((i, dup_tup.index(i)))
print(first_occurence)

# %%
# ### Assignment 7: Unpacking Tuples
# Create a tuple with 5 elements and unpack it into 5 variables. Print the variables.

tuple_of_five = tuple([1,2,3,4,5])
one,two,three,four,five = tuple_of_five

print(one,two,three,four,five)

# %%
# ### Assignment 8: Tuple Conversion
# Convert a list of the first 5 positive integers to a tuple. Print the tuple.

converted_tuple = tuple([i for i in range(1, 6)])
converted_tuple

# %%
# ### Assignment 9: Tuple of Tuples
# Create a tuple containing 3 tuples, each with 3 elements. Print the tuple of tuples.

matrix_tuple = tuple(tuple(random.randint(1,8) for _ in range(3)) for _ in range(3))

for row in matrix_tuple:
    print(row)

# %%
# ### Assignment 11: Tuple and String
# Create a tuple with the characters of a string. Join the tuple elements into a single string. Print the string.

char_tuple = tuple([chr(random.randint(65, 95)) for _ in range(100)])
print(char_tuple)

char_string = ''.join(char_tuple)
print(char_string)

# %%
# ### Assignment 12: Tuple and Dictionary
# Create a dictionary with tuple keys and integer values. Print the dictionary.

temp_dict = {
    (1,2): 23,
    (3,5): 35,
    (4,7): 47,
}

print(temp_dict)

# %%
# ### Assignment 14: Tuple and Set
# Create a tuple with duplicate elements. Convert it to a set to remove duplicates and print the resulting set.

tup_set = tuple(random.randint(1, 5) for _ in range(11))
print(tup_set)
converted_tup_set = set(tup_set)
print(converted_tup_set)

# %%
# ### Assignment 15: Tuple Functions
# Write functions that take a tuple and return the minimum, maximum, and sum of the elements. Print the results for a sample tuple.

temp_tuple = tuple([random.randint(1, 11) for _ in range(1, 10)])

print(temp_tuple)

def math_operations(input_tuple):
    min_val, max_val, sum_val = input_tuple[0], 0, 0
    for i in input_tuple:
        if (i < min_val): min_val = i
        if (i > max_val): max_val = i
        sum_val += i
    ans = f"Min Element is {min_val}, max Element is {max_val}, Total Sum is {sum_val}"
    return ans

print(math_operations(temp_tuple))
